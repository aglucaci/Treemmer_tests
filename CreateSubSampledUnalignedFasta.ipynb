# %%
"""
Given as input

“MACSE2_Out_Codons_recombinants_0.fas.treefile_trimmed_list_RTL_0.8” \
    - a running list of which species is removed after each iteration.

Original alignment = MACSE2_Out_Codons_recombinants_0_renamed.fas



"""

# %%
import sys
import os
from Bio import SeqIO

# %%
#INPUT_ALIGNMENT = "MACSE2_Out_Codons_recombinants_0_renamed.fas"
#RTL_FILE = "MACSE2_Out_Codons_recombinants_0.fas.treefile_trimmed_list_RTL_0.8"

basedir = "p53/"

INPUT_ALIGNMENT = "TP53_refseq_cds_CodonAligned.fas"
RTL_FILE = "PARSED_TREEMER_TRIMMED_LIST.txt"

#RTL_FILE = "TP53_refseq_cds_CodonAligned.nwk_trimmed_list_RTL_0.8" # this is the ones (species) that are left.. not the ones I want.
# I want which species is eliminated (pruned) at each iteration.

#output
path = basedir + "subsampled_fasta"

try:  
    #os.mkdir(path)  
    os.system("mkdir -p " + path)
except OSError as error:  
    print(error)

# %%
## Helper functioneros -------------------------------------------------------------------------------------------
def subsample_fasta(input_fasta, species_to_exclude, output_fasta):
    
    with open(input_fasta, "r") as handle:
        for n, record in enumerate(SeqIO.parse(handle, "fasta")):
            gene_id = record.id 
            gene_desc = record.description
            gene_seq = str(record.seq).replace("-", "")
            
            if gene_id == species_to_exclude: 
                
                print("# match found")
                continue #skip this one
            else:
                #continue with normal output
                with open(output_fasta, "a") as fh:
                    fh.write(">" + gene_id + "\n" + gene_seq + "\n")
                fh.close()

                
            #end if
        #end for
    #end with
    
                
#end method

# %%
## Main subroutine -----------------------------------------------------------------------------------------------

#Checks to implement, if outputfile_exists, this is bad, means we already ran this script.. delete it.

with open(basedir + RTL_FILE, "r") as fh:
    for n, line in enumerate(fh):
        species = line.strip()
        print("Processing:", n, species)
        
        OUTPUT_FILE = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n) + ".fasta"
        
        
        if n == 0: 
            # first time
            #I want a fasta, with everything in the original fasta, except this species.
            #OUTPUT_FILE = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n) + ".fasta"
            subsample_fasta(basedir + INPUT_ALIGNMENT, species, OUTPUT_FILE)   
        else:
            INPUT = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n-1) + ".fasta"
            #OUTPUT_FILE = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n) + ".fasta"
            
            subsample_fasta(INPUT, species, OUTPUT_FILE) 
        #end if
    
        
    #end for
#end with


## End of cell ----------------------------------------------------------------------------------------------------
# Out:
# Processing: 0 NM_000546_6_Homo_sapiens_tumor_protein_p53_TP53_transcript_variant_1_mRNA_1
# # match found
# Processing: 1 XM_029212409_1_PREDICTED_Monodon_monoceros_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 2 XM_006175816_3_PREDICTED_Camelus_ferus_tumor_protein_p53_TP53_mRNA_2
# # match found
# Processing: 3 XM_003810066_3_PREDICTED_Pan_paniscus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 4 XM_025363515_1_PREDICTED_Theropithecus_gelada_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 5 XM_010843072_1_PREDICTED_Bison_bison_bison_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 6 NM_001286289_1_Xiphophorus_maculatus_tumor_protein_p53_tp53_mRNA_1
# # match found
# Processing: 7 NM_001202405_1_Equus_caballus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 8 XM_008530347_1_PREDICTED_Equus_przewalskii_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 9 XM_008687972_1_PREDICTED_Ursus_maritimus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 10 XM_032616755_1_PREDICTED_Phocoena_sinus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 11 XM_027625914_2_PREDICTED_Zalophus_californianus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 12 XM_024748420_1_PREDICTED_Neophocaena_asiaeorientalis_asiaeorientalis_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 13 XM_027130927_1_PREDICTED_Lagenorhynchus_obliquidens_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 14 NM_174201_2_Bos_taurus_tumor_protein_p53_TP53_mRNA_3
# # match found
# Processing: 15 NM_001009403_1_Ovis_aries_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 16 XM_036077514_1_PREDICTED_Halichoerus_grypus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 17 XM_012052423_1_PREDICTED_Cercocebus_atys_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 18 XM_025428522_2_PREDICTED_Canis_lupus_dingo_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 19 XM_030800485_1_PREDICTED_Nomascus_leucogenys_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 20 XM_028124935_1_PREDICTED_Eumetopias_jubatus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 21 XM_034989514_1_PREDICTED_Mirounga_leonina_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 22 XM_011994540_1_PREDICTED_Mandrillus_leucophaeus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 23 NM_001009294_1_Felis_catus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 24 XM_010362387_1_PREDICTED_Rhinopithecus_roxellana_tumor_protein_p53_TP53_mRNA_2
# # match found
# Processing: 25 XM_029701643_1_PREDICTED_Salmo_trutta_cellular_tumor_antigen_p53_LOC115154926_transcript_variant_X1_mRNA_1
# # match found
# Processing: 26 XM_024394883_1_PREDICTED_Oncorhynchus_tshawytscha_cellular_tumor_antigen_p53_LOC112229014_mRNA_1
# # match found
# Processing: 27 XM_021694492_1_PREDICTED_Neomonachus_schauinslandi_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 28 NM_030989_3_Rattus_norvegicus_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 29 XM_006218777_3_PREDICTED_Vicugna_pacos_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 30 XM_032582297_1_PREDICTED_Xiphophorus_hellerii_tumor_protein_p53_tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 31 XM_004571176_4_PREDICTED_Maylandia_zebra_cellular_tumor_antigen_p53_LOC101480650_transcript_variant_X1_mRNA_1
# # match found
# Processing: 32 XM_011358864_2_PREDICTED_Pteropus_vampyrus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 33 XM_031807550_1_PREDICTED_Oncorhynchus_kisutch_tumor_protein_p53_tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 34 XM_023193314_2_PREDICTED_Piliocolobus_tephrosceles_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 35 XM_036836670_1_PREDICTED_Balaenoptera_musculus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 36 XM_032322544_1_PREDICTED_Mustela_erminea_tumor_protein_p53_TP53_transcript_variant_X3_mRNA_1
# # match found
# Processing: 37 XM_030295516_1_PREDICTED_Lynx_canadensis_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 38 XM_014549841_1_PREDICTED_Myotis_brandtii_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 39 XM_022524640_1_PREDICTED_Enhydra_lutris_kenyoni_tumor_protein_p53_LOC111161133_mRNA_1
# # match found
# Processing: 40 XM_029670106_1_PREDICTED_Oncorhynchus_nerka_tumor_protein_p53_tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 41 XM_026520889_1_PREDICTED_Ursus_arctos_horribilis_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 42 XM_023400622_1_PREDICTED_Seriola_lalandi_dorsalis_cellular_tumor_antigen_p53_like_LOC111650698_mRNA_1
# # match found
# Processing: 43 XM_022595620_2_PREDICTED_Delphinapterus_leucas_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 44 XM_015504433_1_PREDICTED_Marmota_marmota_marmota_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_2
# # match found
# Processing: 45 XM_004398491_1_PREDICTED_Odobenus_rosmarus_divergens_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 46 XM_005894802_2_PREDICTED_Bos_mutus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 47 XM_017671764_2_PREDICTED_Manis_javanica_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 48 XM_028499408_1_PREDICTED_Physeter_catodon_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 49 NM_001003210_1_Canis_lupus_familiaris_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 50 XM_003929186_2_PREDICTED_Saimiri_boliviensis_boliviensis_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 51 XM_021177210_2_PREDICTED_Mus_caroli_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 52 XM_006738887_2_PREDICTED_Leptonychotes_weddellii_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 53 XM_033848569_1_PREDICTED_Tursiops_truncatus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 54 XM_014195885_1_PREDICTED_Salmo_salar_tumor_protein_p53_tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 55 XM_032840028_1_PREDICTED_Lontra_canadensis_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 56 XM_032139337_2_PREDICTED_Hylobates_moloch_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 57 NM_001047151_2_Macaca_mulatta_tumor_protein_p53_TP53_mRNA_2
# # match found
# Processing: 58 XM_007457790_1_PREDICTED_Lipotes_vexillifer_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 59 XM_030548110_1_PREDICTED_Gopherus_evgoodei_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 60 XM_019013136_2_PREDICTED_Gorilla_gorilla_gorilla_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 61 XM_030861565_1_PREDICTED_Globicephala_melas_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 62 XM_015562573_1_PREDICTED_Myotis_davidii_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 63 XM_036341447_1_PREDICTED_Myotis_myotis_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 64 XM_003912272_5_PREDICTED_Papio_anubis_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 65 XM_037151170_1_PREDICTED_Artibeus_jamaicensis_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 66 XM_033422971_1_PREDICTED_Orcinus_orca_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 67 XM_005939677_2_PREDICTED_Haplochromis_burtoni_cellular_tumor_antigen_p53_like_LOC102296334_transcript_variant_X1_mRNA_1
# # match found
# Processing: 68 XM_026162037_1_PREDICTED_Astatotilapia_calliptera_cellular_tumor_antigen_p53_like_LOC113018712_mRNA_1
# # match found
# Processing: 69 XM_023968124_1_PREDICTED_Salvelinus_alpinus_cellular_tumor_antigen_p53_LOC111950504_mRNA_1
# # match found
# Processing: 70 XM_027857038_1_PREDICTED_Vombatus_ursinus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 71 XM_028869449_2_PREDICTED_Peromyscus_leucopus_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 72 XM_025864014_1_PREDICTED_Callorhinus_ursinus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 73 XM_005693530_3_PREDICTED_Capra_hircus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 74 XM_027047532_1_PREDICTED_Acinonyx_jubatus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 75 NM_001310270_1_Heterocephalus_glaber_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 76 XM_032280430_1_PREDICTED_Sapajus_apella_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 77 XM_002747948_4_PREDICTED_Callithrix_jacchus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 78 XM_002826974_4_PREDICTED_Pongo_abelii_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 79 XM_025905404_1_PREDICTED_Oreochromis_niloticus_cellular_tumor_antigen_p53_p53_transcript_variant_X1_mRNA_2
# # match found
# Processing: 80 XM_006922335_3_PREDICTED_Pteropus_alecto_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 81 XM_025920288_1_PREDICTED_Puma_concolor_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 82 XM_012776058_2_PREDICTED_Microcebus_murinus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 83 XM_034505539_1_PREDICTED_Arvicanthis_niloticus_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 84 XM_032511329_1_PREDICTED_Etheostoma_spectabile_cellular_tumor_antigen_p53_like_LOC116686339_transcript_variant_X1_mRNA_1
# # match found
# Processing: 85 XM_031298412_2_PREDICTED_Sander_lucioperca_tumor_protein_p53_tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 86 XM_003416902_3_PREDICTED_Loxodonta_africana_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 87 NM_011640_3_Mus_musculus_transformation_related_protein_53_Trp53_transcript_variant_1_mRNA_1
# # match found
# Processing: 88 NM_001243976_1_Cricetulus_griseus_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 89 XM_029927154_1_PREDICTED_Suricata_suricatta_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 90 XM_008010192_1_PREDICTED_Chlorocebus_sabaeus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 91 XM_033091194_1_PREDICTED_Rhinolophus_ferrumequinum_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 92 XM_037028382_1_PREDICTED_Sturnira_hondurensis_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 93 XM_024565104_1_PREDICTED_Desmodus_rotundus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 94 XM_007166385_1_PREDICTED_Balaenoptera_acutorostrata_scammoni_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 95 XM_036197270_1_PREDICTED_Onychomys_torridus_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 96 XM_014789552_1_PREDICTED_Ceratotherium_simum_simum_tumor_protein_p53_LOC101399576_mRNA_1
# # match found
# Processing: 97 XM_028128360_1_PREDICTED_Eptesicus_fuscus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 98 XM_028780049_1_PREDICTED_Grammomys_surdaster_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 99 XM_037492036_1_PREDICTED_Talpa_occidentalis_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 100 XM_033184717_1_PREDICTED_Trachypithecus_francoisi_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 101 NM_001290844_2_Bubalus_bubalis_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 102 XM_031351448_1_PREDICTED_Mastomys_coucha_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 103 XM_002924437_4_PREDICTED_Ailuropoda_melanoleuca_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 104 XM_032431962_1_PREDICTED_Phoca_vitulina_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 105 XM_010614891_3_PREDICTED_Fukomys_damarensis_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 106 NM_001172740_1_Cavia_porcellus_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 107 XM_004638424_2_PREDICTED_Octodon_degus_tumor_protein_p53_Tp53_transcript_variant_X4_mRNA_1
# # match found
# Processing: 108 XM_023283324_2_PREDICTED_Amphiprion_ocellaris_tumor_protein_p53_tp53_mRNA_1
# # match found
# Processing: 109 XM_016931470_2_PREDICTED_Pan_troglodytes_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 110 XM_031965443_1_PREDICTED_Sarcophilus_harrisii_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 111 XM_036766977_1_PREDICTED_Trichosurus_vulpecula_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 112 XM_008573838_1_PREDICTED_Galeopterus_variegatus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 113 NM_001200076_1_Ictalurus_punctatus_tumor_protein_p53_tp53_mRNA_1
# # match found
# Processing: 114 XM_032794536_1_PREDICTED_Chelonoidis_abingdonii_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 115 XM_032912336_1_PREDICTED_Rattus_rattus_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 116 XM_014861557_1_PREDICTED_Equus_asinus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 117 XM_028534686_2_PREDICTED_Phyllostomus_discolor_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 118 XM_016222486_1_PREDICTED_Miniopterus_natalensis_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 119 XM_029525864_1_PREDICTED_Echeneis_naucrates_cellular_tumor_antigen_p53_like_LOC115058519_transcript_variant_X1_mRNA_1
# # match found
# Processing: 120 XM_012806041_2_PREDICTED_Otolemur_garnettii_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 121 XM_008062341_2_PREDICTED_Carlito_syrichta_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 122 XM_012655616_1_PREDICTED_Propithecus_coquereli_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 123 XM_036451999_1_PREDICTED_Pipistrellus_kuhlii_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 124 XM_036269156_1_PREDICTED_Molossus_molossus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 125 XM_004760256_2_PREDICTED_Mustela_putorius_furo_tumor_protein_p53_TP53_transcript_variant_X3_mRNA_1
# # match found
# Processing: 126 NM_001287369_1_Tupaia_chinensis_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 127 XM_026005407_1_PREDICTED_Vulpes_vulpes_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 128 XM_004669213_1_PREDICTED_Jaculus_jaculus_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 129 XM_010996514_2_PREDICTED_Camelus_dromedarius_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 130 NM_001281661_1_Mesocricetus_auratus_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 131 XM_015992323_1_PREDICTED_Peromyscus_maniculatus_bairdii_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 132 XM_005349777_1_PREDICTED_Microtus_ochrogaster_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 133 XM_019413568_1_PREDICTED_Panthera_pardus_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 134 XM_005399463_2_PREDICTED_Chinchilla_lanigera_tumor_protein_p53_Tp53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 135 XM_026353231_1_PREDICTED_Anabas_testudineus_tumor_protein_p53_tp53_mRNA_1
# # match found
# Processing: 136 XM_036895866_1_PREDICTED_Manis_pentadactyla_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 137 XM_029454926_1_PREDICTED_Cottoperca_gobio_cellular_tumor_antigen_p53_like_LOC115023713_mRNA_1
# # match found
# Processing: 138 XM_013007322_2_PREDICTED_Echinops_telfairi_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 139 XM_007952255_1_PREDICTED_Orycteropus_afer_afer_tumor_protein_p53_TP53_mRNA_1
# # match found
# Processing: 140 XM_005332819_3_PREDICTED_Ictidomys_tridecemlineatus_tumor_protein_p53_Tp53_mRNA_1
# # match found
# Processing: 141 XM_020869027_1_PREDICTED_Odocoileus_virginianus_texanus_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 142 XM_019664961_1_PREDICTED_Hipposideros_armiger_tumor_protein_p53_TP53_transcript_variant_X1_mRNA_1
# # match found
# Processing: 143 XM_022210691_1_PREDICTED_Acanthochromis_polyacanthus_cellular_tumor_antigen_p53_like_LOC110962689_transcript_variant_X1_mRNA_1
# # match found
