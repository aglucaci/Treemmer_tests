# %%
"""
Given as input

“MACSE2_Out_Codons_recombinants_0.fas.treefile_trimmed_list_RTL_0.8” \
    - a running list of which species is removed after each iteration.

Original alignment = MACSE2_Out_Codons_recombinants_0_renamed.fas



"""

# %%
import sys
import os
from Bio import SeqIO

# %%
INPUT_ALIGNMENT = "MACSE2_Out_Codons_recombinants_0_renamed.fas"
RTL_FILE = "MACSE2_Out_Codons_recombinants_0.fas.treefile_trimmed_list_RTL_0.8"

path = "subsampled_fasta"

try:  
    #os.mkdir(path)  
    os.system("mkdir -p " + path)
except OSError as error:  
    print(error)

# %%
## Helper functioneros -------------------------------------------------------------------------------------------
def subsample_fasta(input_fasta, species_to_exclude, output_fasta):
    
    with open(input_fasta, "r") as handle:
        for n, record in enumerate(SeqIO.parse(handle, "fasta")):
            gene_id = record.id 
            gene_desc = record.description
            gene_seq = str(record.seq).replace("-", "")
            
            if gene_id == species_to_exclude: 
                
                print("# match found")
                continue #skip this one
            else:
                #continue with normal output
                with open(output_fasta, "a") as fh:
                    fh.write(">" + gene_id + "\n" + gene_seq + "\n")
                fh.close()

                
            #end if
        #end for
    #end with
    
                
#end method

# %%
## Main subroutine -----------------------------------------------------------------------------------------------

#Checks to implement, if outputfile_exists, this is bad, means we already ran this script.. delete it.

with open(RTL_FILE, "r") as fh:
    for n, line in enumerate(fh):
        species = line.strip()
        print("Processing:", n, species)
        
        OUTPUT_FILE = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n) + ".fasta"
        
        if n == 0: 
            # first time
            #I want a fasta, with everything in the original fasta, except this species.
            #OUTPUT_FILE = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n) + ".fasta"
            subsample_fasta(INPUT_ALIGNMENT, species, OUTPUT_FILE)   
        else:
            INPUT = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n-1) + ".fasta"
            #OUTPUT_FILE = path + "/" + INPUT_ALIGNMENT + "_subsampled_" + str(n) + ".fasta"
            
            subsample_fasta(INPUT, species, OUTPUT_FILE) 
        #end if
    
        
    #end for
#end with


## End of cell ----------------------------------------------------------------------------------------------------
# Out:
# Processing: 0 NM_001709.5
# # match found
# Processing: 1 NM_001012441.1
# # match found
# Processing: 2 XM_032283691.1
# # match found
# Processing: 3 XM_008050727.1
# # match found
# Processing: 4 XM_014591303.2
# # match found
# Processing: 5 XM_013019592.1
# # match found
# Processing: 6 XM_010964743.1
# # match found
# Processing: 7 XM_007180991.1
# # match found
# Processing: 8 XM_028501134.1
# # match found
# Processing: 9 XM_005216334.4
# # match found
# Processing: 10 XM_016206154.1
# # match found
# Processing: 11 XM_013147262.2
# # match found
# Processing: 12 XM_004851581.3
# # match found
# Processing: 13 XM_033764060.1
# # match found
# Processing: 14 XM_004644113.2
# # match found
# Processing: 15 XM_008148947.2
# # match found
# Processing: 16 XM_017667612.1
# # match found
# Processing: 17 XM_004682964.2
# # match found
# Processing: 18 XM_004418542.2
# # match found
# Processing: 19 XM_004369733.1
# # match found
# Processing: 20 XM_007497196.2
# # match found
# Processing: 21 XM_031944159.1
# # match found
# Processing: 22 XM_020977976.1
# # match found
# Processing: 23 XM_027852578.1
# # match found
# Processing: 24 XM_029059317.1
# # match found
# Processing: 25 XM_009584497.1
# # match found
# Processing: 26 XM_035550371.1
# # match found
# Processing: 27 XM_015863456.2
# # match found
# Processing: 28 XM_010124146.1
# # match found
# Processing: 29 XM_008946081.1
# # match found
# Processing: 30 XM_026041160.1
# # match found
# Processing: 31 XM_009084069.1
# # match found
# Processing: 32 XM_027705303.1
# # match found
# Processing: 33 XM_005046293.2
# # match found
# Processing: 34 XM_009097040.3
# # match found
# Processing: 35 XM_012573739.3
# # match found
# Processing: 36 XM_009506018.1
# # match found
# Processing: 37 XM_009679447.1
# # match found
# Processing: 38 XM_019519496.1
# # match found
# Processing: 39 XM_008118081.2
# # match found
# Processing: 40 XM_020790423.1
# # match found
# Processing: 41 XM_026704474.1
# # match found
# Processing: 42 XM_035117800.1
# # match found
# Processing: 43 XM_015425686.1
# # match found
# Processing: 44 XM_014574007.2
# # match found
# Processing: 45 XM_005995059.2
# # match found
# Processing: 46 XM_027008950.2
# # match found
# Processing: 47 XM_017458315.1
# # match found
# Processing: 48 XM_022667082.1
# # match found
# Processing: 49 XM_016571672.1
# # match found
# Processing: 50 XM_030766568.1
# # match found
# Processing: 51 XM_028957024.1
# # match found
# Processing: 52 XM_031587459.1
# # match found
# Processing: 53 XM_020053030.2
# # match found
# Processing: 54 XM_029846527.1
# # match found
# Processing: 55 XM_026378593.1
# # match found
# Processing: 56 XM_030376135.1
# # match found
# Processing: 57 XM_019867195.1
# # match found
# Processing: 58 XM_026320191.1
# # match found
# Processing: 59 XM_020713401.2
# # match found
# Processing: 60 XM_030096988.1
# # match found
# Processing: 61 XM_020939026.1
# # match found
# Processing: 62 XM_015953357.1
# # match found
# Processing: 63 XM_021309594.2
# # match found
# Processing: 64 XM_023810716.1
# # match found
# Processing: 65 XM_015338619.1
# # match found
# Processing: 66 XM_028794224.1
# # match found
# Processing: 67 XM_020536678.1
# # match found
# Processing: 68 XM_033038635.1
# # match found
# Processing: 69 XM_007887667.1
# # match found
# Processing: 70 XM_029582984.1
# # match found
# Processing: 71 XM_030199447.1
# # match found
# Processing: 72 XM_033928531.1
# # match found
# Processing: 73 XM_031899708.1
# # match found
# Processing: 74 XM_018567792.1
# # match found
# Processing: 75 XM_006864851.1
# # match found
# Processing: 76 XM_004708253.2
# # match found
# Processing: 77 XM_006883713.1
# # match found
# Processing: 78 XM_004585440.1
# # match found
# Processing: 79 XM_029555090.1
# # match found
# Processing: 80 XM_007653166.4
# # match found
# Processing: 81 NM_001270630.1
# # match found
# Processing: 82 XM_004660846.2
# # match found
# Processing: 83 XM_008584165.1
# # match found
# Processing: 84 XM_020286534.1
# # match found
# Processing: 85 XM_016194241.1
# # match found
# Processing: 86 XM_030333208.1
# # match found
